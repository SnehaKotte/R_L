# %% [markdown]
# <a href="https://colab.research.google.com/github/SnehaKotte/R_L/blob/main/Untitled64.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
M = int(input("Enter number of machines: "))
machines = []
for i in range(M):
    name = input("Enter machine name: ")
    machines.append(name)
print("\nMachines:", machines)
N = [0] * M
R = [0] * M
Q = [0] * M
epsilon = 0.2
N_play = 10
total_reward = 0
print("\n----- Epsilon-Greedy Strategy -----")
for play in range(1, N_play + 1):
    random_number = random.random()
    if random_number < epsilon:
        choice = random.randint(0, M - 1)
        print("\nPlay", play, ": Exploration")
    else:
        choice = Q.index(max(Q))
        print("\nPlay", play, ": Exploitation")
    reward = float(input("Enter reward: "))
    N[choice] = N[choice] + 1
    R[choice] = R[choice] + reward
    Q[choice] = Q[choice] + (reward - Q[choice]) / N[choice]
    total_reward = total_reward + reward
    print("Updated Q-value:", round(Q[choice], 2))
print("\n FINAL RESULTS")
print("Machine\tN\tR\tQ")
for i in range(M):
    print(machines[i], "\t", N[i], "\t", R[i], "\t", round(Q[i], 2))
print("\nTotal reward after 10 plays:", total_reward)-
# Out:
# Enter number of machines: 3
# Enter machine name: A
# Enter machine name: B
# Enter machine name: C
#
# Machines: ['A', 'B', 'C']
#
# ----- Epsilon-Greedy Strategy -----
#
# Play 1 : Exploitation
# Enter reward: 3
# Updated Q-value: 3.0
#
# Play 2 : Exploitation
# Enter reward: 4
# Updated Q-value: 3.5
#
# Play 3 : Exploitation
# Enter reward: 6
# Updated Q-value: 4.33
#
# Play 4 : Exploration
# Enter reward: 5
# Updated Q-value: 5.0
#
# Play 5 : Exploration
# Enter reward: 4
# Updated Q-value: 4.0
#
# Play 6 : Exploration
# Enter reward: 3
# Updated Q-value: 4.0
#
# Play 7 : Exploitation
# Enter reward: 7
# Updated Q-value: 5.0
#
# Play 8 : Exploration
# Enter reward: 2
# Updated Q-value: 4.4
#
# Play 9 : Exploitation
# Enter reward: 4
# Updated Q-value: 4.33
#
# Play 10 : Exploitation
# Enter reward: 6
# Updated Q-value: 4.57
#
#  FINAL RESULTS
# Machine	N	R	Q
# A 	 7 	 32.0 	 4.57
# B 	 2 	 8.0 	 4.0
# C 	 1 	 4.0 	 4.0
#
# Total reward after 10 plays: 44.0
